cccp_times = np.array([206.10, 13049, 1931, 2377, 1380, 2008])
pp_vals = np.array([nltcs_train_pp, plant_train_pp, jester_train_pp, ps_train_pp, dna_train_pp, 6.8])
pp_cccp = np.array([nltcs_cccp, plant_cccp, jester_cccp, ps_cccp, dna_cccp, 6.05])

# %%
print "CCCP > Adam > PGD"

fig, ax = plt.subplots()
w = 0.21
rects1 = ax.bar(range(N), pp_vals, width=w, color='r')
rects2 = ax.bar(np.arange(N)+w, tf_vals, width=w, color='b')
rects3 = ax.bar(np.arange(N)+2*w, pp_cccp, width=w, color='orange')
ax.set_ylabel("-log(Pr(x|w))")
ax.set_title("Log Likelyhoods for different algos")
ax.set_xticks(np.arange(N) + w)
ax.set_xticklabels(("NLTCS", "Plant", "Jester", "Pumsb-star", "DNA", "MSNBC"))
ax.legend((rects1[0], rects2[0], rects3[0]), ("PGD", "Adam", "CCCP"))
# Out:
# CCCP > Adam > PGD

# %%
fig, ax = plt.subplots()
w = 0.22
rects1 = ax.bar(range(N), pp_times, width=w, color='r')
rects2 = ax.bar(np.arange(N)+w, tf_times, width=w, color='b')
rects3 = ax.bar(np.arange(N)+2*w, cccp_times, width=w, color='orange')
ax.set_ylabel("Time in Seconds")
ax.set_title("Time for different algos")
ax.set_xticks(np.arange(N) + w)
ax.set_xticklabels(("NLTCS", "Plant", "Jester", "Pumsb-star", "DNA", "MSNBC"))
ax.legend((rects1[0], rects2[0], rects3[0]), ("PGD", "Adam", "CCCP"))

# %%
print "CCCP > Adam > PGD"

fig, ax = plt.subplots()
w = 0.21
print 1.0/np.mean((tf_vals-pp_cccp)/(pp_vals-pp_cccp))
rects1 = ax.bar(range(N), (pp_vals-pp_cccp)/(pp_vals-pp_cccp), width=w, color='r')
rects2 = ax.bar(np.arange(N)+w, (tf_vals-pp_cccp)/(pp_vals-pp_cccp), width=w, color='b')
ax.set_ylabel("-log(Pr(x|w))")
ax.set_title("Normalized Error in Log Likelyhoods for different algos")
ax.set_xticks(np.arange(N) + w)
ax.set_xticklabels(("NLTCS", "Plant", "Jester", "Pumsb-star", "DNA", "MSNBC"))
ax.legend((rects1[0], rects2[0]), ("PGD", "Adam"))
# Out:
# CCCP > Adam > PGD
# 2.61187622398

# %%
fig, ax = plt.subplots()
print np.mean(pp_times/tf_times)
w = 0.22
rects1 = ax.bar(range(N), pp_times/tf_times, width=w, color='r')
rects2 = ax.bar(np.arange(N)+w, tf_times/tf_times, width=w, color='b')
rects3 = ax.bar(np.arange(N)+2*w, cccp_times/tf_times, width=w, color='orange')
ax.set_ylabel("Time in Seconds")
ax.set_title("Time for different algos")
ax.set_xticks(np.arange(N) + w)
ax.set_xticklabels(("NLTCS", "Plant", "Jester", "Pumsb-star", "DNA", "MSNBC"))
ax.legend((rects1[0], rects2[0], rects3[0]), ("PGD", "Adam", "CCCP"))
# Out:
# 9.78023484862
