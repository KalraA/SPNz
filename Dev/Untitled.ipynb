# %%
from SPN import *

# %%
S = SPN('nltcs.spn.txt')

# %%
S.start_sess()

# %%
len(S.leaf_id)
# Out:
# 787

# %%
inp = [[1], [0]]*787

# %%
% timeit S.predict(inp)
# Out:
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# [[ 0.17896136]]
# ...

# %%
S.train(data, 50)
